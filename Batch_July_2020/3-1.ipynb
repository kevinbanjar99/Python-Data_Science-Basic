# %% [markdown]
# <h2>Soal 1: Pemahaman Component Matplotlib</h2>
#
# - Jelaskan apa itu Figure
# - Jelaskan apa itu Axis

# %% [markdown]
# jawab:
#
# Figure merupakan sebuah window atau halaman untuk menampilkan suatu objek visual dari data. (Diabaratkan seperti kita melukis pada sebuah kanvas, maka kanvas tersebut adalah figure)
#
# Axis merupakan suatu area atau pun dimensi pada figure yang berperan sebagai tempat dimana data akan diplot. Axis juga memiliki berbagai macam komponen seperti x-axis, y-axis, dan sebagainya.

# %% [markdown]
# <h2>Soal 2: Membuat Component Figure dan Axis</h2>
#
# - Buatlah Figure dan Axis kosong tanpa Data
# - Plot data di bawah ini dengan 2 cara, yaitu dengan membuat figure dan axis secara explicit dan Implicit

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 20, 100)
y = np.cos(x/2)

# %%
# Figure dan Axis Kosong
print('Figure dan Axis Kosong :')
fig = plt.figure()
ax = fig.add_subplot()
plt.show()

# Explicit
print('Cara Explicit :')
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x, y)
plt.show()

# Implicit
print('Cara Implicit :')
plt.plot(x, y)
plt.show()
# Out:
# Figure dan Axis Kosong :
# Cara Explicit :
# Cara Implicit :

# %% [markdown]
# Exected Output:
#
# ![alt text](https://drive.google.com/uc?id=1mq8HMFwz5GlTH_SPAFnXZZ8KnBWBC9d3)

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=156xwVvDgShvIPBefimXg18zfFjz_SQ8X)

# %% [markdown]
# <h2>Soal 3: Memasukan multiple data ke dalam satu axis</h2>
#
# - Plot ketiga data berikut ke dalam satu axis, dan gunakan seaborn style
# - save data tersebut dengan nama file bebas

# %%
x = np.linspace(0, 20, 100)
y = np.cos(x/2)
y2 = np.sin(x)
y3 = np.sin(2*x)

# %%
# Plot Data 
print('Plot Data :')
fig, ax = plt.subplots()
ax.plot(x, y)
ax.plot(x, y2)
ax.plot(x, y3)
plt.style.use('seaborn')
plt.show()


# Save Data
from IPython.display import Image

fig.savefig('figure.png')
print('Data Tersimpan :')
Image('figure.png') # Menguji data yang telah tersimpan
# Out:
# Plot Data :
# Data Tersimpan :

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=1EnJDnXuJ97NZ9EcKQWRaGCD7-LroZ-Gj)
