# %% [markdown]
# # Assignment 1: Theoritical Understanding
#
# Explain the diffirences between Univariate, Bivariate, and Multivariate Analysis !

# %% [markdown]
# Answer :
#
#
# *   Univariate, analyzing at one variable
# *   Bivariate, analyzing at two variables and their relationship
# *   Multivariate, analyzing at more than two variables and their relationship

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = sns.load_dataset('penguins')
df
# Out:
#     species     island  bill_length_mm  ...  flipper_length_mm  body_mass_g     sex
# 0    Adelie  Torgersen            39.1  ...              181.0       3750.0    Male
# 1    Adelie  Torgersen            39.5  ...              186.0       3800.0  Female
# 2    Adelie  Torgersen            40.3  ...              195.0       3250.0  Female
# 3    Adelie  Torgersen             NaN  ...                NaN          NaN     NaN
# 4    Adelie  Torgersen            36.7  ...              193.0       3450.0  Female
# ..      ...        ...             ...  ...                ...          ...     ...
# 339  Gentoo     Biscoe             NaN  ...                NaN          NaN     NaN
# 340  Gentoo     Biscoe            46.8  ...              215.0       4850.0  Female
# 341  Gentoo     Biscoe            50.4  ...              222.0       5750.0    Male
# 342  Gentoo     Biscoe            45.2  ...              212.0       5200.0  Female
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# # Assignment 2. Data Preparation
#
# *   Remove the missing value in the dataset rows using the .dropna() attribute.
#
# *   Penform the data grouping using the 'species' column using the mean() aggregation function.

# %%
#code here

df_edit = df.dropna(axis=0)
df_edit = df_edit.groupby(['species'])[['bill_length_mm','bill_depth_mm','flipper_length_mm','body_mass_g']].mean()
df_edit
# Out:
#            bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# species
# Adelie          38.823973      18.347260         190.102740  3706.164384
# Chinstrap       48.833824      18.420588         195.823529  3733.088235
# Gentoo          47.568067      14.996639         217.235294  5092.436975

# %% [markdown]
# Expected output:
#
# ![tanpa handling missing value](https://drive.google.com/uc?id=1OnuXmscVRqduqT_TYI1vB291rpXM4D_1)

# %% [markdown]
# # Assignment 3. Univariate Analysis
# Create a univariate analysis using these below instructions :
#
# *   Create a Pie Plot from the grouped dataset for flipper_length_mm column to obtain the expected output.
# *   Create a histogram plot from the initial dataset for body_mass_g column.
# *   Explain the insight that you got from those two graphs.

# %%
#code here
plot = df_edit.plot.pie(y='flipper_length_mm', figsize=(8, 8), legend = False, autopct='%1.1f%%')

plot.axes.xaxis.set_visible(False)
plot.axes.yaxis.set_visible(False)

plt.grid(True)
plt.show()

# %%
ax = df.plot.hist(y = 'body_mass_g', legend=False, figsize=(10, 8),xlabel='Body_mass_g', ylabel='Count')
ax.set(xlabel='Body_mass_g', ylabel='Count')

plt.show()

# %% [markdown]
# Expected Output:
#
#
# Pie Chart
#
# ![](https://drive.google.com/uc?id=11H6X7xpEeodPWD56tHBhV4sLrJ-6B-Bd)
#
# Histogram
#
# ![](https://drive.google.com/uc?id=1A_twS7BbQhkGvUz7zAWgye7q3ZRTQkhi)

# %% [markdown]
# Analysis :
# 1. From the Pie Plot, it can be seen that each species only has a slight difference if we compare it based from its flipper length. We can order from the species that has the longest flipper length to the smallest as : Gentoo, Chinstrap, and Adelie.
# 2. From the histograph, it can be seen that the mode of the data based on the its body mass is between 3500 to 4500 gram with the count is around 65 to 70 data.

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# # Assignment 4. Bivariate Analysis
#
#
#
# *   Create a catplot graph using seaborn with x='sex', y='bill_length_mm', and kind='bar' to produce the expected output.
# *   Create a scatter plot using seaborn with x='body_mass_g', y='flipper_length_mm', and hue='bill_length_mm' to produce the expected output.
# *   Explain the insight that you got from those two graphs.

# %%
#code here
g1 = sns.catplot(x="sex",y="bill_length_mm", data=df, kind="bar")

# %%
sns.set({'figure.figsize':(13,13)})
g2 = sns.scatterplot(x="body_mass_g", y="flipper_length_mm", hue="bill_length_mm", data=df)

# %% [markdown]
# Expected Output:
#
# Catplot
#
# ![](https://drive.google.com/uc?id=1imCbGD9cWqXUjd33tAh6D0OH20vVpWea)
#
# Scatter plot
#
# ![](https://drive.google.com/uc?id=1_k734IpRYq6Q1wF57hwzSEjnVd2Sii2Z)

# %% [markdown]
# Analysis:
#
# 1. From the categorical plot, males has the longer bill length if we compare it to females.

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# # Soal 5. Multivariate Analisis
#
# *   By using seaborn, create a pairplot of all feature data in the dataset (df) with the argument kind='bar' to produce the expected output.
# *   Explain the insight that you got from those two graphs.

# %%
#code here

pair = sns.pairplot(df, kind='scatter', diag_kind='hist')

# %% [markdown]
# Expected output:
#
# Pair plot
#
# ![](https://drive.google.com/uc?id=1td8WAZLJEW5BPTq-wEJyZ4soRNNLXfqX)

# %% [markdown]
# Analisa:

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---
